# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("train.csv")
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df['Embarked'][0])
# Out:
# str

# %%
df['Embarked'] = df['Embarked'].astype('category')
# type(df['Embarked'])

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# dtype: object

# %%
type(df['Embarked'][0])
# Out:
# str

# %%
import matplotlib.cm as cm
X= df[['Pclass', 'Name', 'Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']]
y = df[['PassengerId','Survived']]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

scatter = pd.scatter_matrix(X_train, marker = 'o', hist_kwds={'bins':15}, figsize=(9,9))
plt.show()
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead

# %%
X_train
# Out:
#      Pclass                                               Name     Sex   Age  \
# 105       3                              Mionoff, Mr. Stoytcho    male  28.0
# 68        3                    Andersson, Miss. Erna Alexandra  female  17.0
# 253       3                           Lobb, Mr. William Arthur    male  30.0
# 320       3                                 Dennis, Mr. Samuel    male  22.0
# 706       2                      Kelly, Mrs. Florence "Fannie"  female  45.0
# 271       3                       Tornquist, Mr. William Henry    male  25.0
# 424       3                        Rosblom, Mr. Viktor Richard    male  18.0
# 752       3                   Vande Velde, Mr. Johannes Joseph    male  33.0
# 615       2                                Herman, Miss. Alice  female  24.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 882       3                       Dahlberg, Miss. Gerda Ulrika  female  22.0
# ...

# %%
y_train
# Out:
#      Survived
# 105         0
# 68          1
# 253         0
# 320         0
# 706         1
# 271         1
# 424         0
# 752         0
# 615         1
# 2           1
# 882         0
# 467         0
# 403         0
# 258         1
# 720         1
# 272         1
# 154         0
# 832         0
# 820         1
# 382         0
# 20          0
# 585         1
# 65          1
# 680         0
# 878         0
# 304         0
# 823         1
# 521         0
# 333         0
# 698         0
# ..        ...
# 72          0
# 845         0
# 537         1
# 677         1
# 849         1
# 874         1
# 174         0
# 87          0
# 551         0
# 486         1
# 705         0
# 314         0
# 396         0
# 600         1
# 472         1
# 70          0
# 599         1
# 804         1
# 754         1
# 277         0
# 723         0
# 9           1
# 359         1
# 707         1
# 763         1
# 835         1
# 192         1
# 629         0
# 559         1
# 684         0
#
# ...

# %%
X_test
# Out:
#      Pclass                                               Name     Sex    Age  \
# 495       3                              Yousseff, Mr. Gerious    male    NaN
# 648       3                                 Willey, Mr. Edward    male    NaN
# 278       3                                 Rice, Master. Eric    male   7.00
# 31        1     Spencer, Mrs. William Augustus (Marie Eugenie)  female    NaN
# 255       3            Touma, Mrs. Darwis (Hanne Youssef Razi)  female  29.00
# 298       1                              Saalfeld, Mr. Adolphe    male    NaN
# 609       1                          Shutes, Miss. Elizabeth W  female  40.00
# 318       1                           Wick, Miss. Mary Natalie  female  31.00
# 484       1                            Bishop, Mr. Dickinson H    male  25.00
# 367       3                     Moussa, Mrs. (Mantoura Boulos)  female    NaN
# 704       3                            Hansen, Mr. Henrik Juul    male  26.00
# ...

# %%
y_train
# Out:
#      PassengerId  Survived
# 105          106         0
# 68            69         1
# 253          254         0
# 320          321         0
# 706          707         1
# 271          272         1
# 424          425         0
# 752          753         0
# 615          616         1
# 2              3         1
# 882          883         0
# 467          468         0
# 403          404         0
# 258          259         1
# 720          721         1
# 272          273         1
# 154          155         0
# 832          833         0
# 820          821         1
# 382          383         0
# 20            21         0
# 585          586         1
# 65            66         1
# 680          681         0
# 878          879         0
# 304          305         0
# 823          824         1
# 521          522         0
# 333          334         0
# 698          699         0
# ..           ...       ...
# 72            73         0
# 845          846         0
# ...

# %%
y_train
# Out:
#      PassengerId  Survived
# 105          106         0
# 68            69         1
# 253          254         0
# 320          321         0
# 706          707         1
# 271          272         1
# 424          425         0
# 752          753         0
# 615          616         1
# 2              3         1
# 882          883         0
# 467          468         0
# 403          404         0
# 258          259         1
# 720          721         1
# 272          273         1
# 154          155         0
# 832          833         0
# 820          821         1
# 382          383         0
# 20            21         0
# 585          586         1
# 65            66         1
# 680          681         0
# 878          879         0
# 304          305         0
# 823          824         1
# 521          522         0
# 333          334         0
# 698          699         0
# ..           ...       ...
# 72            73         0
# 845          846         0
# ...

# %%
y_test
# Out:
#      PassengerId  Survived
# 495          496         0
# 648          649         0
# 278          279         0
# 31            32         1
# 255          256         1
# 298          299         1
# 609          610         1
# 318          319         1
# 484          485         1
# 367          368         1
# 704          705         0
# 346          347         1
# 196          197         0
# 535          536         1
# 310          311         1
# 14            15         0
# 350          351         0
# 145          146         0
# 614          615         0
# 803          804         1
# 144          145         0
# 708          709         1
# 778          779         0
# 270          271         0
# 474          475         0
# 319          320         1
# 519          520         0
# 141          142         1
# 880          881         1
# 642          643         0
# ..           ...       ...
# 727          728         1
# 428          429         0
# ...

# %%
# plotting a 3D scatter plot
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_train['Pclass'], X_train['Age'], X_train['Fare'] )
ax.set_xlabel('Pclass')
ax.set_ylabel('Age')
ax.set_zlabel('Fare')
plt.show()

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Embarked'] = df['Embarked'].astype('category')

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 1)
X= df[['Pclass','Age','SibSp','Parch','Fare','Embarked' ]]
y = df[['PassengerId','Survived']]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare Embarked
# 105       3  28.0      0      0    7.8958        S
# 68        3  17.0      4      2    7.9250        S
# 253       3  30.0      1      0   16.1000        S
# 320       3  22.0      0      0    7.2500        S
# 706       2  45.0      0      0   13.5000        S
# 271       3  25.0      0      0    0.0000        S
# 424       3  18.0      1      1   20.2125        S
# 752       3  33.0      0      0    9.5000        S
# 615       2  24.0      1      2   65.0000        S
# 2         3  26.0      0      0    7.9250        S
# 882       3  22.0      0      0   10.5167        S
# 467       1  56.0      0      0   26.5500        S
# 403       3  28.0      1      0   15.8500        S
# 258       1  35.0      0      0  512.3292        C
# 720       2   6.0      0      1   33.0000        S
# 272       2  41.0      0      1   19.5000        S
# 154       3   NaN      0      0    7.3125        S
# ...

# %%
y_train
# Out:
#      PassengerId  Survived
# 105          106         0
# 68            69         1
# 253          254         0
# 320          321         0
# 706          707         1
# 271          272         1
# 424          425         0
# 752          753         0
# 615          616         1
# 2              3         1
# 882          883         0
# 467          468         0
# 403          404         0
# 258          259         1
# 720          721         1
# 272          273         1
# 154          155         0
# 832          833         0
# 820          821         1
# 382          383         0
# 20            21         0
# 585          586         1
# 65            66         1
# 680          681         0
# 878          879         0
# 304          305         0
# 823          824         1
# 521          522         0
# 333          334         0
# 698          699         0
# ..           ...       ...
# 72            73         0
# 845          846         0
# ...

# %%
X_test
# Out:
#      Pclass    Age  SibSp  Parch      Fare Embarked
# 495       3    NaN      0      0   14.4583        C
# 648       3    NaN      0      0    7.5500        S
# 278       3   7.00      4      1   29.1250        Q
# 31        1    NaN      1      0  146.5208        C
# 255       3  29.00      0      2   15.2458        C
# 298       1    NaN      0      0   30.5000        S
# 609       1  40.00      0      0  153.4625        S
# 318       1  31.00      0      2  164.8667        S
# 484       1  25.00      1      0   91.0792        C
# 367       3    NaN      0      0    7.2292        C
# 704       3  26.00      1      0    7.8542        S
# 346       2  40.00      0      0   13.0000        S
# 196       3    NaN      0      0    7.7500        Q
# 535       2   7.00      0      2   26.2500        S
# 310       1  24.00      0      0   83.1583        C
# 14        3  14.00      0      0    7.8542        S
# 350       3  23.00      0      0    9.2250        S
# ...

# %%
y_test
# Out:
#      PassengerId  Survived
# 495          496         0
# 648          649         0
# 278          279         0
# 31            32         1
# 255          256         1
# 298          299         1
# 609          610         1
# 318          319         1
# 484          485         1
# 367          368         1
# 704          705         0
# 346          347         1
# 196          197         0
# 535          536         1
# 310          311         1
# 14            15         0
# 350          351         0
# 145          146         0
# 614          615         0
# 803          804         1
# 144          145         0
# 708          709         1
# 778          779         0
# 270          271         0
# 474          475         0
# 319          320         1
# 519          520         0
# 141          142         1
# 880          881         1
# 642          643         0
# ..           ...       ...
# 727          728         1
# 428          429         0
# ...

# %%
knn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-3a355426b06f> in <module>()
# ----> 1 knn.fit(X_train, y_train)
#
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     759         """
#     760         if not isinstance(X, (KDTree, BallTree)):
# --> 761             X, y = check_X_y(X, y, "csr", multi_output=True)
#     762
#     763         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 30)
X= df[['Pclass','SibSp','Parch','Fare' ]]
y = df[['Survived']]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
knn.fit(X_train,y_train)
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=30, p=2,
#            weights='uniform')

# %%
knn.score(X_test,y_test)
# Out:
# 0.726457399103139

# %%
knn.predict([[20, 43,55,20.3]])
# Out:
# array([0])

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# dtype: object
